# %%
import tweepy
import datetime
import csv

from tweepy import OAuthHandler, Stream, StreamListener

consumer_key="QYvHeIdpM7MuxDNYpvDmTO6gf"
consumer_secret="kk81ZHN31ZMCGeioVieXH9xevucVVrAYwSSEiPQhTQrUXfd3K2"
access_token="289218050-v6AisxlJUmVkv3jLcJo1599ZVxp3rsoJjUyz6NPW"
access_token_secret="FN8r1nz2SVbloma4mobVGut5VF4Ch4lT2DWGKL8rL4bZf"
auth = OAuthHandler(consumer_key, consumer_secret,)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
tweets = api.home_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# [방송] 오늘 (10/25) PM5:00 KBS2 &lt;뮤직뱅크&gt; 에 #투모로우바이투게더 가 출연합니다.
# 모든 걸 다 바쳐도 아깝지 않은 ABNEW에게 오늘 무대를 선물할게요😊 ABNEW‼️ 잘 받았죠⁉️
#
# #AB6IX #BLIND_FOR_LOVE #6IXENSE #에이비식스 #임영민 #전웅 #김동현 #박우진… https://t.co/hkkpRTcZRY
# GOT7 Jackson
# "MIRRORS"
#
# Released Online :
# iTunes &amp; Apple Music https://t.co/LtR00SyZ8o
# Spotify… https://t.co/lygc8MPsd0
# [#AB6IX/🎥] 심플리 케이팝 'BLIND FOR LOVE'
#
# LINK : https://t.co/rX7pg94LTg
#
# #BLIND_FOR_LOVE #6IXENSE #에이비식스 #임영민 #전웅 #김동현… https://t.co/X16rSawm6V
# GOT7 Jackson
# "MIRRORS"
#
# Released Online :
# iTunes &amp; Apple Music https://t.co/5Q6q0UN97h
# Spotify… https://t.co/VE9Sz3p1Hd
# GOT7 Jackson “TITANIC (feat. Rich Brian)” M/V
# https://t.co/vNzQCSeir7
#
# #GOT7 #갓세븐
# #Jackson #잭슨
# #MIRRORS #OCT25
# #JacksonWang1stAlbum
# GOT7 Jackson “TITANIC (feat. Rich Brian)” M/V
# https://t.co/hYAbr3UcIY
#
# #GOT7 #갓세븐
# #Jackson #잭슨
# #MIRRORS #OCT25
# #JacksonWang1stAlbum
# [#AB6IX/📢] AB6IX가 2020 대한민국 퍼스트브랜드 신인상 후보에 올랐습니다🥳 소중한 한 표 부탁드립니다🥰
#
# ...

# %%
user_tweets = api.user_timeline(screen_name='agnezmo', count=200, tweet_mode="extended")
for tweet in user_tweets:
    print(tweet._json)
# Out:
# {'created_at': 'Tue Oct 22 15:23:09 +0000 2019', 'id': 1186664295498518528, 'id_str': '1186664295498518528', 'full_text': 'RT @MikeGNitevision: 🔥 🔥 🔥 Let’s GOOOOOOOO https://t.co/aMGkCGAyU8', 'truncated': False, 'display_text_range': [0, 66], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'MikeGNitevision', 'name': 'Mike G™\u200e', 'id': 26191241, 'id_str': '26191241', 'indices': [3, 19]}], 'urls': [{'url': 'https://t.co/aMGkCGAyU8', 'expanded_url': 'https://twitter.com/agnezmo/status/1186575860813320192', 'display_url': 'twitter.com/agnezmo/status…', 'indices': [43, 66]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 42420346, 'id_str': '42420346', 'name': 'AGNEZ MO', 'screen_name': 'agnezmo', 'location': 'Los Angeles', 'descrip
# ...

# %%
the_list = []
tweet_agnezmo = api.user_timeline(screen_name='agnezmo', count=200, tweet_mode="extended")
startDate = datetime.datetime(2019, 10, 22, 00, 00, 00)
endDate =   datetime.datetime(2019, 10, 24, 00, 00, 00)

for tweet in tweet_agnezmo:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        the_list.append(tweet._json)

# %%
import pandas
myData = pandas.DataFrame(the_list)
myData
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Oct 22 15:23:09 +0000 2019  1186664295498518528  1186664295498518528
# 1  Tue Oct 22 09:31:45 +0000 2019  1186575860813320192  1186575860813320192
# 2  Tue Oct 22 09:31:12 +0000 2019  1186575724355866624  1186575724355866624
# 3  Tue Oct 22 08:21:50 +0000 2019  1186558267536756736  1186558267536756736
#
#                                            full_text  truncated  \
# 0  RT @MikeGNitevision: 🔥 🔥 🔥 Let’s GOOOOOOOO htt...      False
# 1             ❤️❤️❤️❤️🙏🏼🙏🏼🙏🏼 https://t.co/oiDFKTiNpw      False
# 2  Out now!! https://t.co/oiDFKTiNpw https://t.co...      False
# 3  FINALLY!!! I AM LEGAL!! LMAO :p - AGNEZ MO htt...      False
#
#   display_text_range                                           entities  \
# 0            [0, 66]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1            [0, 38]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
csvFile = open('tugas.csv', 'a')
csvWriter = csv.writer(csvFile)
for tweet in  tweepy.Cursor(api.search,q="#BTS", lang="en",count=20, since="2019-10-10").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
